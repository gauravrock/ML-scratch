# %% [markdown]
# #### This is the bi-class logistic regression for mushroom dataset classifying them as poisonous or edible using gradient descent algo..

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#importing dataset using pandas
raw_data = pd.read_csv("../dataset/lung_cancer_examples.csv");

# %%
raw_data.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
print(raw_data.info())# to check the categorical data in the dataframe
raw_data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
# Name       59 non-null object
# Surname    59 non-null object
# Age        59 non-null int64
# Smokes     59 non-null int64
# AreaQ      59 non-null int64
# Alkhol     59 non-null int64
# Result     59 non-null int64
# dtypes: int64(5), object(2)
# memory usage: 3.3+ KB
# None
# (59, 7)

# %%
#applying data preprocessing to remove categorical data columns for now!!1
pure_raw_data = raw_data.iloc[:,2:raw_data.shape[1]] # fetching all the  necessary columns from the raw_data
pure_raw_data = pd.DataFrame(pure_raw_data)

# %%
total_size = pure_raw_data.shape[0]
train_index = int(0.7 * total_size)
train_index
# Out:
# 41

# %%
#separating data into training ans testing
training_data = pure_raw_data.iloc[0:train_index]
pure_training_data = training_data.iloc[:,0:training_data.shape[1]-1]#creating pure training data withour class labels

testing_data = pure_raw_data[train_index:total_size]
pure_testing_data = testing_data.iloc[:,0:testing_data.shape[1]-1]#creating pure training data withour class labels
print(pure_training_data.head(),"\n\n\n",pure_testing_data.head())
# Out:
#    Age  Smokes  AreaQ  Alkhol
# 0   35       3      5       4
# 1   27      20      2       5
# 2   30       0      5       2
# 3   28       0      8       1
# 4   68       4      5       6
#
#
#      Age  Smokes  AreaQ  Alkhol
# 41   47      12      8       0
# 42   69      20      5       4
# 43   63      20      4       5
# 44   39      15      7       2
# 45   21      20      8       3

# %%
#separating class labels from pure training and testing data  
C_train = training_data["Result"]
C_train = np.array(C_train)
C_train = C_train.reshape(C_train.shape[0],1)

C_test  = testing_data["Result"]
C_test = np.array(C_test)
C_test = C_test.reshape(C_test.shape[0],1)
print("C_train:{}\nC_test:{}".format(C_train.shape,C_test.shape))
# Out:
# C_train:(41, 1)
# C_test:(18, 1)

# %%
#applying feature scaling or normalization on data  by Dividing Each Row of Training Data with respective Row Maximium Value to Normalize the Dataset
pure_training_data = np.array(pure_training_data)
pure_training_data = pure_training_data/np.max(pure_training_data,axis=0)
pure_testing_data = np.array(pure_testing_data)
pure_testing_data = pure_testing_data/np.max(pure_testing_data,axis=0)
print(pure_training_data.shape,"\n",pure_testing_data.shape)
# Out:
# (41, 4)
#  (18, 4)

# %%
#applying gradient descent algorithm 
alpha = 0.1      # learning rate hyperparameter
epsilon = 0.0000001# error tolerance hyperparameter


Q0_initial = np.random.randn(1,1)
Q1_initial = np.random.randn(pure_training_data.shape[1],1)
print(Q0_initial.shape,Q1_initial.shape)
# Out:
# (1, 1) (4, 1)

# %%
N = pure_training_data.shape[0]
x = pure_training_data.T
i=0
iterations=[]
loss = []


while (True):
    power = Q0_initial + np.matmul(pure_training_data,Q1_initial)
    sigmoid_function = 1/(1 + np.exp(-power))
    dels = sigmoid_function - C_train
    c = np.dot(x,dels)

    cost_function_theta0 = np.mean(dels)
    cost_function_theta1 = np.mean(c)

    #putting values of derivattive in gradient descent
    Q0_new = Q0_initial - (alpha * cost_function_theta0)
    Q1_new = Q1_initial - (alpha * cost_function_theta1)

    function_old = (-np.matmul(C_train.T,np.log(sigmoid_function))- np.matmul((1-C_train).T,np.log(1-sigmoid_function)))/N


    power_final = Q0_new + np.matmul(pure_training_data,Q1_new)
    sigmoid_function_new = 1/(1 + np.exp(-power_final))
    function_new = (-np.matmul(C_train.T,np.log(sigmoid_function_new))- np.matmul((1-C_train).T,np.log(1-sigmoid_function_new)))/N 
    
    if abs(function_new-function_old)<epsilon:
        break
    i += 1
    iterations.append(i)
    loss.append(function_old)
    print("The cost function {} in iteration {}".format(function_old,i))
    Q0_initial = Q0_new
    Q1_initial = Q1_new
# Out:
# The cost function [[1.19234546]] in iteration 1
# The cost function [[1.06058008]] in iteration 2
# The cost function [[1.05727597]] in iteration 3
# The cost function [[1.05636452]] in iteration 4
# The cost function [[1.05546435]] in iteration 5
# The cost function [[1.05456603]] in iteration 6
# The cost function [[1.05366954]] in iteration 7
# The cost function [[1.05277487]] in iteration 8
# The cost function [[1.05188202]] in iteration 9
# The cost function [[1.05099099]] in iteration 10
# The cost function [[1.05010178]] in iteration 11
# The cost function [[1.04921438]] in iteration 12
# The cost function [[1.0483288]] in iteration 13
# The cost function [[1.04744502]] in iteration 14
# The cost function [[1.04656306]] in iteration 15
# The cost function [[1.0456829]] in iteration 16
# The cost function [[1.04480455]] in iteration 17
# The cost function [[1.043928]] in iteration 18
# The cost function [[1.04305326]] in iteration 19
# The cost function [[1.04218031]] in iteration 20
# The cost function [[1.04130916]] in iteration 21
# The cost function [[1.04043981]] in iteration 22
# The cost function [[1.03957225]] in iteration 23
# The cost function [[1.03870649]] in iteration 24
# The cost function [[1.03784251]] in iteration 25
# The cost function [[1.03698032]] in iteration 26
# The cost function [[1.03611992]] in iteration 27
# The cost function [[1.03526131]] in iteration 28
# The cost function [[1.03440447]] in iteration 29
# The cost function [[1.03354942]] in iteration 30
# The cost function [[1.03269614]] in iteration 31
# The cost function [[1.03184464]] in iteration 32
# The cost function [[1.03099492]] in iteration 33
# The cost function [[1.03014696]] in iteration 34
# The cost function [[1.02930078]] in iteration 35
# The cost function [[1.02845637]] in iteration 36
# The cost function [[1.02761372]] in iteration 37
# The cost function [[1.02677283]] in iteration 38
# The cost function [[1.02593371]] in iteration 39
# The cost function [[1.02509635]] in iteration 40
# The cost function [[1.02426074]] in iteration 41
# The cost function [[1.02342689]] in iteration 42
# The cost function [[1.02259479]] in iteration 43
# The cost function [[1.02176445]] in iteration 44
# The cost function [[1.02093585]] in iteration 45
# The cost function [[1.020109]] in iteration 46
# The cost function [[1.0192839]] in iteration 47
# The cost function [[1.01846054]] in iteration 48
# The cost function [[1.01763892]] in iteration 49
# The cost function [[1.01681903]] in iteration 50
# The cost function [[1.01600089]] in iteration 51
# The cost function [[1.01518447]] in iteration 52
# The cost function [[1.01436979]] in iteration 53
# The cost function [[1.01355684]] in iteration 54
# The cost function [[1.01274562]] in iteration 55
# The cost function [[1.01193612]] in iteration 56
# The cost function [[1.01112834]] in iteration 57
# The cost function [[1.01032228]] in iteration 58
# The cost function [[1.00951794]] in iteration 59
# The cost function [[1.00871532]] in iteration 60
# The cost function [[1.00791441]] in iteration 61
# The cost function [[1.00711521]] in iteration 62
# The cost function [[1.00631773]] in iteration 63
# The cost function [[1.00552195]] in iteration 64
# The cost function [[1.00472787]] in iteration 65
# The cost function [[1.00393549]] in iteration 66
# The cost function [[1.00314482]] in iteration 67
# The cost function [[1.00235584]] in iteration 68
# The cost function [[1.00156856]] in iteration 69
# The cost function [[1.00078297]] in iteration 70
# The cost function [[0.99999907]] in iteration 71
# The cost function [[0.99921686]] in iteration 72
# The cost function [[0.99843633]] in iteration 73
# The cost function [[0.99765749]] in iteration 74
# The cost function [[0.99688033]] in iteration 75
# The cost function [[0.99610485]] in iteration 76
# The cost function [[0.99533104]] in iteration 77
# The cost function [[0.99455891]] in iteration 78
# The cost function [[0.99378845]] in iteration 79
# The cost function [[0.99301966]] in iteration 80
# The cost function [[0.99225253]] in iteration 81
# The cost function [[0.99148707]] in iteration 82
# The cost function [[0.99072327]] in iteration 83
# The cost function [[0.98996113]] in iteration 84
# The cost function [[0.98920065]] in iteration 85
# The cost function [[0.98844182]] in iteration 86
# The cost function [[0.98768464]] in iteration 87
# The cost function [[0.98692911]] in iteration 88
# The cost function [[0.98617523]] in iteration 89
# The cost function [[0.98542299]] in iteration 90
# The cost function [[0.9846724]] in iteration 91
# The cost function [[0.98392344]] in iteration 92
# The cost function [[0.98317613]] in iteration 93
# The cost function [[0.98243044]] in iteration 94
# The cost function [[0.98168639]] in iteration 95
# The cost function [[0.98094397]] in iteration 96
# The cost function [[0.98020317]] in iteration 97
# The cost function [[0.979464]] in iteration 98
# The cost function [[0.97872645]] in iteration 99
# The cost function [[0.97799052]] in iteration 100
# The cost function [[0.97725621]] in iteration 101
# The cost function [[0.97652351]] in iteration 102
# The cost function [[0.97579242]] in iteration 103
# The cost function [[0.97506295]] in iteration 104
# The cost function [[0.97433507]] in iteration 105
# The cost function [[0.97360881]] in iteration 106
# The cost function [[0.97288414]] in iteration 107
# The cost function [[0.97216107]] in iteration 108
# The cost function [[0.9714396]] in iteration 109
# The cost function [[0.97071973]] in iteration 110
# The cost function [[0.97000144]] in iteration 111
# The cost function [[0.96928474]] in iteration 112
# The cost function [[0.96856963]] in iteration 113
# The cost function [[0.9678561]] in iteration 114
# The cost function [[0.96714416]] in iteration 115
# The cost function [[0.96643379]] in iteration 116
# The cost function [[0.96572499]] in iteration 117
# The cost function [[0.96501777]] in iteration 118
# The cost function [[0.96431212]] in iteration 119
# The cost function [[0.96360804]] in iteration 120
# The cost function [[0.96290552]] in iteration 121
# The cost function [[0.96220456]] in iteration 122
# The cost function [[0.96150516]] in iteration 123
# The cost function [[0.96080732]] in iteration 124
# The cost function [[0.96011104]] in iteration 125
# The cost function [[0.95941631]] in iteration 126
# The cost function [[0.95872312]] in iteration 127
# The cost function [[0.95803148]] in iteration 128
# The cost function [[0.95734139]] in iteration 129
# The cost function [[0.95665284]] in iteration 130
# The cost function [[0.95596582]] in iteration 131
# The cost function [[0.95528034]] in iteration 132
# The cost function [[0.9545964]] in iteration 133
# The cost function [[0.95391398]] in iteration 134
# The cost function [[0.95323309]] in iteration 135
# The cost function [[0.95255373]] in iteration 136
# The cost function [[0.95187589]] in iteration 137
# The cost function [[0.95119957]] in iteration 138
# The cost function [[0.95052476]] in iteration 139
# The cost function [[0.94985147]] in iteration 140
# The cost function [[0.94917969]] in iteration 141
# The cost function [[0.94850942]] in iteration 142
# The cost function [[0.94784066]] in iteration 143
# The cost function [[0.9471734]] in iteration 144
# The cost function [[0.94650764]] in iteration 145
# The cost function [[0.94584337]] in iteration 146
# The cost function [[0.94518061]] in iteration 147
# The cost function [[0.94451933]] in iteration 148
# The cost function [[0.94385955]] in iteration 149
# The cost function [[0.94320125]] in iteration 150
# The cost function [[0.94254444]] in iteration 151
# The cost function [[0.9418891]] in iteration 152
# The cost function [[0.94123525]] in iteration 153
# The cost function [[0.94058287]] in iteration 154
# The cost function [[0.93993197]] in iteration 155
# The cost function [[0.93928254]] in iteration 156
# The cost function [[0.93863457]] in iteration 157
# The cost function [[0.93798807]] in iteration 158
# The cost function [[0.93734303]] in iteration 159
# The cost function [[0.93669946]] in iteration 160
# The cost function [[0.93605734]] in iteration 161
# The cost function [[0.93541667]] in iteration 162
# The cost function [[0.93477745]] in iteration 163
# The cost function [[0.93413969]] in iteration 164
# The cost function [[0.93350336]] in iteration 165
# The cost function [[0.93286849]] in iteration 166
# The cost function [[0.93223505]] in iteration 167
# The cost function [[0.93160305]] in iteration 168
# The cost function [[0.93097248]] in iteration 169
# The cost function [[0.93034335]] in iteration 170
# The cost function [[0.92971565]] in iteration 171
# The cost function [[0.92908937]] in iteration 172
# The cost function [[0.92846452]] in iteration 173
# The cost function [[0.92784108]] in iteration 174
# The cost function [[0.92721907]] in iteration 175
# The cost function [[0.92659847]] in iteration 176
# The cost function [[0.92597929]] in iteration 177
# The cost function [[0.92536151]] in iteration 178
# The cost function [[0.92474514]] in iteration 179
# The cost function [[0.92413018]] in iteration 180
# The cost function [[0.92351661]] in iteration 181
# The cost function [[0.92290445]] in iteration 182
# The cost function [[0.92229368]] in iteration 183
# The cost function [[0.92168431]] in iteration 184
# The cost function [[0.92107632]] in iteration 185
# The cost function [[0.92046973]] in iteration 186
# The cost function [[0.91986452]] in iteration 187
# The cost function [[0.91926069]] in iteration 188
# The cost function [[0.91865824]] in iteration 189
# The cost function [[0.91805716]] in iteration 190
# The cost function [[0.91745747]] in iteration 191
# The cost function [[0.91685914]] in iteration 192
# The cost function [[0.91626218]] in iteration 193
# The cost function [[0.91566658]] in iteration 194
# The cost function [[0.91507235]] in iteration 195
# The cost function [[0.91447948]] in iteration 196
# The cost function [[0.91388797]] in iteration 197
# The cost function [[0.91329781]] in iteration 198
# The cost function [[0.912709]] in iteration 199
# The cost function [[0.91212154]] in iteration 200
# The cost function [[0.91153543]] in iteration 201
# The cost function [[0.91095066]] in iteration 202
# The cost function [[0.91036723]] in iteration 203
# The cost function [[0.90978514]] in iteration 204
# The cost function [[0.90920439]] in iteration 205
# The cost function [[0.90862496]] in iteration 206
# The cost function [[0.90804687]] in iteration 207
# The cost function [[0.9074701]] in iteration 208
# The cost function [[0.90689466]] in iteration 209
# The cost function [[0.90632054]] in iteration 210
# The cost function [[0.90574773]] in iteration 211
# The cost function [[0.90517625]] in iteration 212
# The cost function [[0.90460607]] in iteration 213
# The cost function [[0.90403721]] in iteration 214
# The cost function [[0.90346965]] in iteration 215
# The cost function [[0.9029034]] in iteration 216
# The cost function [[0.90233845]] in iteration 217
# The cost function [[0.9017748]] in iteration 218
# The cost function [[0.90121244]] in iteration 219
# The cost function [[0.90065138]] in iteration 220
# The cost function [[0.90009161]] in iteration 221
# The cost function [[0.89953312]] in iteration 222
# The cost function [[0.89897593]] in iteration 223
# The cost function [[0.89842001]] in iteration 224
# The cost function [[0.89786538]] in iteration 225
# The cost function [[0.89731202]] in iteration 226
# The cost function [[0.89675993]] in iteration 227
# The cost function [[0.89620912]] in iteration 228
# The cost function [[0.89565958]] in iteration 229
# The cost function [[0.8951113]] in iteration 230
# The cost function [[0.89456429]] in iteration 231
# The cost function [[0.89401853]] in iteration 232
# The cost function [[0.89347404]] in iteration 233
# The cost function [[0.8929308]] in iteration 234
# The cost function [[0.89238881]] in iteration 235
# The cost function [[0.89184807]] in iteration 236
# The cost function [[0.89130858]] in iteration 237
# The cost function [[0.89077033]] in iteration 238
# The cost function [[0.89023332]] in iteration 239
# The cost function [[0.88969756]] in iteration 240
# The cost function [[0.88916302]] in iteration 241
# The cost function [[0.88862973]] in iteration 242
# The cost function [[0.88809766]] in iteration 243
# The cost function [[0.88756682]] in iteration 244
# The cost function [[0.8870372]] in iteration 245
# The cost function [[0.88650881]] in iteration 246
# The cost function [[0.88598164]] in iteration 247
# The cost function [[0.88545568]] in iteration 248
# The cost function [[0.88493094]] in iteration 249
# The cost function [[0.88440741]] in iteration 250
# The cost function [[0.88388509]] in iteration 251
# The cost function [[0.88336397]] in iteration 252
# The cost function [[0.88284406]] in iteration 253
# The cost function [[0.88232535]] in iteration 254
# The cost function [[0.88180784]] in iteration 255
# The cost function [[0.88129152]] in iteration 256
# The cost function [[0.88077639]] in iteration 257
# The cost function [[0.88026246]] in iteration 258
# The cost function [[0.87974971]] in iteration 259
# The cost function [[0.87923815]] in iteration 260
# The cost function [[0.87872776]] in iteration 261
# The cost function [[0.87821856]] in iteration 262
# The cost function [[0.87771054]] in iteration 263
# The cost function [[0.87720368]] in iteration 264
# The cost function [[0.876698]] in iteration 265
# The cost function [[0.87619349]] in iteration 266
# The cost function [[0.87569015]] in iteration 267
# The cost function [[0.87518796]] in iteration 268
# The cost function [[0.87468694]] in iteration 269
# The cost function [[0.87418708]] in iteration 270
# The cost function [[0.87368837]] in iteration 271
# The cost function [[0.87319081]] in iteration 272
# The cost function [[0.8726944]] in iteration 273
# The cost function [[0.87219914]] in iteration 274
# The cost function [[0.87170503]] in iteration 275
# The cost function [[0.87121206]] in iteration 276
# The cost function [[0.87072022]] in iteration 277
# The cost function [[0.87022953]] in iteration 278
# The cost function [[0.86973996]] in iteration 279
# The cost function [[0.86925153]] in iteration 280
# The cost function [[0.86876423]] in iteration 281
# The cost function [[0.86827805]] in iteration 282
# The cost function [[0.867793]] in iteration 283
# The cost function [[0.86730907]] in iteration 284
# The cost function [[0.86682626]] in iteration 285
# The cost function [[0.86634456]] in iteration 286
# The cost function [[0.86586398]] in iteration 287
# The cost function [[0.8653845]] in iteration 288
# The cost function [[0.86490614]] in iteration 289
# The cost function [[0.86442888]] in iteration 290
# The cost function [[0.86395272]] in iteration 291
# The cost function [[0.86347767]] in iteration 292
# The cost function [[0.86300371]] in iteration 293
# The cost function [[0.86253084]] in iteration 294
# The cost function [[0.86205907]] in iteration 295
# The cost function [[0.86158839]] in iteration 296
# The cost function [[0.8611188]] in iteration 297
# The cost function [[0.86065029]] in iteration 298
# The cost function [[0.86018286]] in iteration 299
# The cost function [[0.85971651]] in iteration 300
# The cost function [[0.85925124]] in iteration 301
# The cost function [[0.85878705]] in iteration 302
# The cost function [[0.85832393]] in iteration 303
# The cost function [[0.85786187]] in iteration 304
# The cost function [[0.85740089]] in iteration 305
# The cost function [[0.85694096]] in iteration 306
# The cost function [[0.8564821]] in iteration 307
# The cost function [[0.8560243]] in iteration 308
# The cost function [[0.85556756]] in iteration 309
# The cost function [[0.85511187]] in iteration 310
# The cost function [[0.85465723]] in iteration 311
# The cost function [[0.85420364]] in iteration 312
# The cost function [[0.8537511]] in iteration 313
# The cost function [[0.8532996]] in iteration 314
# The cost function [[0.85284914]] in iteration 315
# The cost function [[0.85239972]] in iteration 316
# The cost function [[0.85195134]] in iteration 317
# The cost function [[0.851504]] in iteration 318
# The cost function [[0.85105768]] in iteration 319
# The cost function [[0.8506124]] in iteration 320
# The cost function [[0.85016814]] in iteration 321
# The cost function [[0.8497249]] in iteration 322
# The cost function [[0.84928269]] in iteration 323
# The cost function [[0.8488415]] in iteration 324
# The cost function [[0.84840132]] in iteration 325
# The cost function [[0.84796216]] in iteration 326
# The cost function [[0.84752401]] in iteration 327
# The cost function [[0.84708687]] in iteration 328
# The cost function [[0.84665074]] in iteration 329
# The cost function [[0.84621561]] in iteration 330
# The cost function [[0.84578149]] in iteration 331
# The cost function [[0.84534836]] in iteration 332
# The cost function [[0.84491623]] in iteration 333
# The cost function [[0.8444851]] in iteration 334
# The cost function [[0.84405496]] in iteration 335
# The cost function [[0.84362581]] in iteration 336
# The cost function [[0.84319764]] in iteration 337
# The cost function [[0.84277046]] in iteration 338
# The cost function [[0.84234427]] in iteration 339
# The cost function [[0.84191905]] in iteration 340
# The cost function [[0.84149482]] in iteration 341
# The cost function [[0.84107156]] in iteration 342
# The cost function [[0.84064927]] in iteration 343
# The cost function [[0.84022795]] in iteration 344
# The cost function [[0.8398076]] in iteration 345
# The cost function [[0.83938822]] in iteration 346
# The cost function [[0.8389698]] in iteration 347
# The cost function [[0.83855234]] in iteration 348
# The cost function [[0.83813585]] in iteration 349
# The cost function [[0.83772031]] in iteration 350
# The cost function [[0.83730572]] in iteration 351
# The cost function [[0.83689208]] in iteration 352
# The cost function [[0.8364794]] in iteration 353
# The cost function [[0.83606766]] in iteration 354
# The cost function [[0.83565687]] in iteration 355
# The cost function [[0.83524701]] in iteration 356
# The cost function [[0.8348381]] in iteration 357
# The cost function [[0.83443013]] in iteration 358
# The cost function [[0.83402309]] in iteration 359
# The cost function [[0.83361699]] in iteration 360
# The cost function [[0.83321182]] in iteration 361
# The cost function [[0.83280757]] in iteration 362
# The cost function [[0.83240426]] in iteration 363
# The cost function [[0.83200186]] in iteration 364
# The cost function [[0.83160039]] in iteration 365
# The cost function [[0.83119984]] in iteration 366
# The cost function [[0.8308002]] in iteration 367
# The cost function [[0.83040148]] in iteration 368
# The cost function [[0.83000368]] in iteration 369
# The cost function [[0.82960678]] in iteration 370
# The cost function [[0.82921079]] in iteration 371
# The cost function [[0.82881571]] in iteration 372
# The cost function [[0.82842153]] in iteration 373
# The cost function [[0.82802825]] in iteration 374
# The cost function [[0.82763587]] in iteration 375
# The cost function [[0.82724439]] in iteration 376
# The cost function [[0.8268538]] in iteration 377
# The cost function [[0.8264641]] in iteration 378
# The cost function [[0.8260753]] in iteration 379
# The cost function [[0.82568738]] in iteration 380
# The cost function [[0.82530035]] in iteration 381
# The cost function [[0.8249142]] in iteration 382
# The cost function [[0.82452893]] in iteration 383
# The cost function [[0.82414455]] in iteration 384
# The cost function [[0.82376103]] in iteration 385
# The cost function [[0.8233784]] in iteration 386
# The cost function [[0.82299663]] in iteration 387
# The cost function [[0.82261574]] in iteration 388
# The cost function [[0.82223571]] in iteration 389
# The cost function [[0.82185655]] in iteration 390
# The cost function [[0.82147826]] in iteration 391
# The cost function [[0.82110082]] in iteration 392
# The cost function [[0.82072425]] in iteration 393
# The cost function [[0.82034853]] in iteration 394
# The cost function [[0.81997367]] in iteration 395
# The cost function [[0.81959965]] in iteration 396
# The cost function [[0.81922649]] in iteration 397
# The cost function [[0.81885418]] in iteration 398
# The cost function [[0.81848272]] in iteration 399
# The cost function [[0.8181121]] in iteration 400
# The cost function [[0.81774232]] in iteration 401
# The cost function [[0.81737338]] in iteration 402
# The cost function [[0.81700528]] in iteration 403
# The cost function [[0.81663802]] in iteration 404
# The cost function [[0.81627159]] in iteration 405
# The cost function [[0.81590599]] in iteration 406
# The cost function [[0.81554122]] in iteration 407
# The cost function [[0.81517727]] in iteration 408
# The cost function [[0.81481416]] in iteration 409
# The cost function [[0.81445186]] in iteration 410
# The cost function [[0.81409039]] in iteration 411
# The cost function [[0.81372974]] in iteration 412
# The cost function [[0.8133699]] in iteration 413
# The cost function [[0.81301088]] in iteration 414
# The cost function [[0.81265267]] in iteration 415
# The cost function [[0.81229527]] in iteration 416
# The cost function [[0.81193868]] in iteration 417
# The cost function [[0.8115829]] in iteration 418
# The cost function [[0.81122792]] in iteration 419
# The cost function [[0.81087374]] in iteration 420
# The cost function [[0.81052036]] in iteration 421
# The cost function [[0.81016779]] in iteration 422
# The cost function [[0.80981601]] in iteration 423
# The cost function [[0.80946502]] in iteration 424
# The cost function [[0.80911482]] in iteration 425
# The cost function [[0.80876542]] in iteration 426
# The cost function [[0.8084168]] in iteration 427
# The cost function [[0.80806898]] in iteration 428
# The cost function [[0.80772193]] in iteration 429
# The cost function [[0.80737567]] in iteration 430
# The cost function [[0.80703019]] in iteration 431
# The cost function [[0.80668548]] in iteration 432
# The cost function [[0.80634155]] in iteration 433
# The cost function [[0.8059984]] in iteration 434
# The cost function [[0.80565602]] in iteration 435
# The cost function [[0.80531441]] in iteration 436
# The cost function [[0.80497357]] in iteration 437
# The cost function [[0.80463349]] in iteration 438
# The cost function [[0.80429418]] in iteration 439
# The cost function [[0.80395563]] in iteration 440
# The cost function [[0.80361784]] in iteration 441
# The cost function [[0.80328081]] in iteration 442
# The cost function [[0.80294454]] in iteration 443
# The cost function [[0.80260902]] in iteration 444
# The cost function [[0.80227426]] in iteration 445
# The cost function [[0.80194024]] in iteration 446
# The cost function [[0.80160698]] in iteration 447
# The cost function [[0.80127446]] in iteration 448
# The cost function [[0.80094269]] in iteration 449
# The cost function [[0.80061166]] in iteration 450
# The cost function [[0.80028137]] in iteration 451
# The cost function [[0.79995182]] in iteration 452
# The cost function [[0.79962301]] in iteration 453
# The cost function [[0.79929493]] in iteration 454
# The cost function [[0.79896759]] in iteration 455
# The cost function [[0.79864098]] in iteration 456
# The cost function [[0.7983151]] in iteration 457
# The cost function [[0.79798995]] in iteration 458
# The cost function [[0.79766552]] in iteration 459
# The cost function [[0.79734182]] in iteration 460
# The cost function [[0.79701885]] in iteration 461
# The cost function [[0.79669659]] in iteration 462
# The cost function [[0.79637505]] in iteration 463
# The cost function [[0.79605423]] in iteration 464
# The cost function [[0.79573412]] in iteration 465
# The cost function [[0.79541473]] in iteration 466
# The cost function [[0.79509605]] in iteration 467
# The cost function [[0.79477807]] in iteration 468
# The cost function [[0.79446081]] in iteration 469
# The cost function [[0.79414425]] in iteration 470
# The cost function [[0.7938284]] in iteration 471
# The cost function [[0.79351325]] in iteration 472
# The cost function [[0.7931988]] in iteration 473
# The cost function [[0.79288504]] in iteration 474
# The cost function [[0.79257199]] in iteration 475
# The cost function [[0.79225963]] in iteration 476
# The cost function [[0.79194796]] in iteration 477
# The cost function [[0.79163699]] in iteration 478
# The cost function [[0.7913267]] in iteration 479
# The cost function [[0.79101711]] in iteration 480
# The cost function [[0.7907082]] in iteration 481
# The cost function [[0.79039997]] in iteration 482
# The cost function [[0.79009243]] in iteration 483
# The cost function [[0.78978557]] in iteration 484
# The cost function [[0.78947938]] in iteration 485
# The cost function [[0.78917388]] in iteration 486
# The cost function [[0.78886905]] in iteration 487
# The cost function [[0.78856489]] in iteration 488
# The cost function [[0.78826141]] in iteration 489
# The cost function [[0.7879586]] in iteration 490
# The cost function [[0.78765645]] in iteration 491
# The cost function [[0.78735498]] in iteration 492
# The cost function [[0.78705417]] in iteration 493
# The cost function [[0.78675402]] in iteration 494
# The cost function [[0.78645454]] in iteration 495
# The cost function [[0.78615571]] in iteration 496
# The cost function [[0.78585754]] in iteration 497
# The cost function [[0.78556004]] in iteration 498
# The cost function [[0.78526318]] in iteration 499
# The cost function [[0.78496698]] in iteration 500
# The cost function [[0.78467143]] in iteration 501
# The cost function [[0.78437653]] in iteration 502
# The cost function [[0.78408228]] in iteration 503
# The cost function [[0.78378868]] in iteration 504
# The cost function [[0.78349572]] in iteration 505
# The cost function [[0.78320341]] in iteration 506
# The cost function [[0.78291173]] in iteration 507
# The cost function [[0.7826207]] in iteration 508
# The cost function [[0.78233031]] in iteration 509
# The cost function [[0.78204055]] in iteration 510
# The cost function [[0.78175143]] in iteration 511
# The cost function [[0.78146294]] in iteration 512
# The cost function [[0.78117508]] in iteration 513
# The cost function [[0.78088786]] in iteration 514
# The cost function [[0.78060126]] in iteration 515
# The cost function [[0.78031529]] in iteration 516
# The cost function [[0.78002995]] in iteration 517
# The cost function [[0.77974523]] in iteration 518
# The cost function [[0.77946113]] in iteration 519
# The cost function [[0.77917765]] in iteration 520
# The cost function [[0.77889479]] in iteration 521
# The cost function [[0.77861255]] in iteration 522
# The cost function [[0.77833092]] in iteration 523
# The cost function [[0.77804991]] in iteration 524
# The cost function [[0.77776952]] in iteration 525
# The cost function [[0.77748973]] in iteration 526
# The cost function [[0.77721055]] in iteration 527
# The cost function [[0.77693198]] in iteration 528
# The cost function [[0.77665402]] in iteration 529
# The cost function [[0.77637666]] in iteration 530
# The cost function [[0.7760999]] in iteration 531
# The cost function [[0.77582375]] in iteration 532
# The cost function [[0.7755482]] in iteration 533
# The cost function [[0.77527324]] in iteration 534
# The cost function [[0.77499889]] in iteration 535
# The cost function [[0.77472512]] in iteration 536
# The cost function [[0.77445196]] in iteration 537
# The cost function [[0.77417938]] in iteration 538
# The cost function [[0.7739074]] in iteration 539
# The cost function [[0.773636]] in iteration 540
# The cost function [[0.7733652]] in iteration 541
# The cost function [[0.77309498]] in iteration 542
# The cost function [[0.77282534]] in iteration 543
# The cost function [[0.77255629]] in iteration 544
# The cost function [[0.77228782]] in iteration 545
# The cost function [[0.77201993]] in iteration 546
# The cost function [[0.77175262]] in iteration 547
# The cost function [[0.77148589]] in iteration 548
# The cost function [[0.77121973]] in iteration 549
# The cost function [[0.77095415]] in iteration 550
# The cost function [[0.77068914]] in iteration 551
# The cost function [[0.7704247]] in iteration 552
# The cost function [[0.77016083]] in iteration 553
# The cost function [[0.76989753]] in iteration 554
# The cost function [[0.7696348]] in iteration 555
# The cost function [[0.76937263]] in iteration 556
# The cost function [[0.76911103]] in iteration 557
# The cost function [[0.76884999]] in iteration 558
# The cost function [[0.76858951]] in iteration 559
# The cost function [[0.7683296]] in iteration 560
# The cost function [[0.76807024]] in iteration 561
# The cost function [[0.76781143]] in iteration 562
# The cost function [[0.76755319]] in iteration 563
# The cost function [[0.76729549]] in iteration 564
# The cost function [[0.76703835]] in iteration 565
# The cost function [[0.76678176]] in iteration 566
# The cost function [[0.76652572]] in iteration 567
# The cost function [[0.76627023]] in iteration 568
# The cost function [[0.76601529]] in iteration 569
# The cost function [[0.76576089]] in iteration 570
# The cost function [[0.76550704]] in iteration 571
# The cost function [[0.76525373]] in iteration 572
# The cost function [[0.76500096]] in iteration 573
# The cost function [[0.76474873]] in iteration 574
# The cost function [[0.76449704]] in iteration 575
# The cost function [[0.76424589]] in iteration 576
# The cost function [[0.76399527]] in iteration 577
# The cost function [[0.76374519]] in iteration 578
# The cost function [[0.76349564]] in iteration 579
# The cost function [[0.76324662]] in iteration 580
# The cost function [[0.76299813]] in iteration 581
# The cost function [[0.76275017]] in iteration 582
# The cost function [[0.76250274]] in iteration 583
# The cost function [[0.76225584]] in iteration 584
# The cost function [[0.76200946]] in iteration 585
# The cost function [[0.76176361]] in iteration 586
# The cost function [[0.76151827]] in iteration 587
# The cost function [[0.76127346]] in iteration 588
# The cost function [[0.76102917]] in iteration 589
# The cost function [[0.7607854]] in iteration 590
# The cost function [[0.76054214]] in iteration 591
# The cost function [[0.7602994]] in iteration 592
# The cost function [[0.76005717]] in iteration 593
# The cost function [[0.75981546]] in iteration 594
# The cost function [[0.75957426]] in iteration 595
# The cost function [[0.75933357]] in iteration 596
# The cost function [[0.75909339]] in iteration 597
# The cost function [[0.75885371]] in iteration 598
# The cost function [[0.75861455]] in iteration 599
# The cost function [[0.75837588]] in iteration 600
# The cost function [[0.75813773]] in iteration 601
# The cost function [[0.75790007]] in iteration 602
# The cost function [[0.75766292]] in iteration 603
# The cost function [[0.75742626]] in iteration 604
# The cost function [[0.75719011]] in iteration 605
# The cost function [[0.75695445]] in iteration 606
# The cost function [[0.75671929]] in iteration 607
# The cost function [[0.75648462]] in iteration 608
# The cost function [[0.75625045]] in iteration 609
# The cost function [[0.75601677]] in iteration 610
# The cost function [[0.75578358]] in iteration 611
# The cost function [[0.75555088]] in iteration 612
# The cost function [[0.75531868]] in iteration 613
# The cost function [[0.75508695]] in iteration 614
# The cost function [[0.75485572]] in iteration 615
# The cost function [[0.75462497]] in iteration 616
# The cost function [[0.7543947]] in iteration 617
# The cost function [[0.75416492]] in iteration 618
# The cost function [[0.75393561]] in iteration 619
# The cost function [[0.75370679]] in iteration 620
# The cost function [[0.75347845]] in iteration 621
# The cost function [[0.75325058]] in iteration 622
# The cost function [[0.75302319]] in iteration 623
# The cost function [[0.75279628]] in iteration 624
# The cost function [[0.75256984]] in iteration 625
# The cost function [[0.75234387]] in iteration 626
# The cost function [[0.75211837]] in iteration 627
# The cost function [[0.75189335]] in iteration 628
# The cost function [[0.75166879]] in iteration 629
# The cost function [[0.7514447]] in iteration 630
# The cost function [[0.75122108]] in iteration 631
# The cost function [[0.75099793]] in iteration 632
# The cost function [[0.75077523]] in iteration 633
# The cost function [[0.75055301]] in iteration 634
# The cost function [[0.75033124]] in iteration 635
# The cost function [[0.75010994]] in iteration 636
# The cost function [[0.74988909]] in iteration 637
# The cost function [[0.74966871]] in iteration 638
# The cost function [[0.74944878]] in iteration 639
# The cost function [[0.7492293]] in iteration 640
# The cost function [[0.74901029]] in iteration 641
# The cost function [[0.74879172]] in iteration 642
# The cost function [[0.74857361]] in iteration 643
# The cost function [[0.74835596]] in iteration 644
# The cost function [[0.74813875]] in iteration 645
# The cost function [[0.74792199]] in iteration 646
# The cost function [[0.74770568]] in iteration 647
# The cost function [[0.74748982]] in iteration 648
# The cost function [[0.7472744]] in iteration 649
# The cost function [[0.74705943]] in iteration 650
# The cost function [[0.7468449]] in iteration 651
# The cost function [[0.74663081]] in iteration 652
# The cost function [[0.74641717]] in iteration 653
# The cost function [[0.74620397]] in iteration 654
# The cost function [[0.7459912]] in iteration 655
# The cost function [[0.74577888]] in iteration 656
# The cost function [[0.74556699]] in iteration 657
# The cost function [[0.74535553]] in iteration 658
# The cost function [[0.74514452]] in iteration 659
# The cost function [[0.74493393]] in iteration 660
# The cost function [[0.74472378]] in iteration 661
# The cost function [[0.74451406]] in iteration 662
# The cost function [[0.74430477]] in iteration 663
# The cost function [[0.74409591]] in iteration 664
# The cost function [[0.74388748]] in iteration 665
# The cost function [[0.74367948]] in iteration 666
# The cost function [[0.7434719]] in iteration 667
# The cost function [[0.74326475]] in iteration 668
# The cost function [[0.74305802]] in iteration 669
# The cost function [[0.74285171]] in iteration 670
# The cost function [[0.74264583]] in iteration 671
# The cost function [[0.74244037]] in iteration 672
# The cost function [[0.74223532]] in iteration 673
# The cost function [[0.7420307]] in iteration 674
# The cost function [[0.74182649]] in iteration 675
# The cost function [[0.7416227]] in iteration 676
# The cost function [[0.74141933]] in iteration 677
# The cost function [[0.74121637]] in iteration 678
# The cost function [[0.74101382]] in iteration 679
# The cost function [[0.74081169]] in iteration 680
# The cost function [[0.74060997]] in iteration 681
# The cost function [[0.74040866]] in iteration 682
# The cost function [[0.74020775]] in iteration 683
# The cost function [[0.74000726]] in iteration 684
# The cost function [[0.73980717]] in iteration 685
# The cost function [[0.73960749]] in iteration 686
# The cost function [[0.73940822]] in iteration 687
# The cost function [[0.73920935]] in iteration 688
# The cost function [[0.73901088]] in iteration 689
# The cost function [[0.73881282]] in iteration 690
# The cost function [[0.73861515]] in iteration 691
# The cost function [[0.73841789]] in iteration 692
# The cost function [[0.73822103]] in iteration 693
# The cost function [[0.73802456]] in iteration 694
# The cost function [[0.7378285]] in iteration 695
# The cost function [[0.73763282]] in iteration 696
# The cost function [[0.73743755]] in iteration 697
# The cost function [[0.73724267]] in iteration 698
# The cost function [[0.73704818]] in iteration 699
# The cost function [[0.73685408]] in iteration 700
# The cost function [[0.73666038]] in iteration 701
# The cost function [[0.73646706]] in iteration 702
# The cost function [[0.73627414]] in iteration 703
# The cost function [[0.7360816]] in iteration 704
# The cost function [[0.73588945]] in iteration 705
# The cost function [[0.73569769]] in iteration 706
# The cost function [[0.73550631]] in iteration 707
# The cost function [[0.73531532]] in iteration 708
# The cost function [[0.73512471]] in iteration 709
# The cost function [[0.73493449]] in iteration 710
# The cost function [[0.73474464]] in iteration 711
# The cost function [[0.73455518]] in iteration 712
# The cost function [[0.7343661]] in iteration 713
# The cost function [[0.73417739]] in iteration 714
# The cost function [[0.73398907]] in iteration 715
# The cost function [[0.73380112]] in iteration 716
# The cost function [[0.73361354]] in iteration 717
# The cost function [[0.73342635]] in iteration 718
# The cost function [[0.73323952]] in iteration 719
# The cost function [[0.73305307]] in iteration 720
# The cost function [[0.732867]] in iteration 721
# The cost function [[0.73268129]] in iteration 722
# The cost function [[0.73249595]] in iteration 723
# The cost function [[0.73231099]] in iteration 724
# The cost function [[0.73212639]] in iteration 725
# The cost function [[0.73194216]] in iteration 726
# The cost function [[0.7317583]] in iteration 727
# The cost function [[0.7315748]] in iteration 728
# The cost function [[0.73139167]] in iteration 729
# The cost function [[0.7312089]] in iteration 730
# The cost function [[0.7310265]] in iteration 731
# The cost function [[0.73084446]] in iteration 732
# The cost function [[0.73066278]] in iteration 733
# The cost function [[0.73048146]] in iteration 734
# The cost function [[0.7303005]] in iteration 735
# The cost function [[0.7301199]] in iteration 736
# The cost function [[0.72993966]] in iteration 737
# The cost function [[0.72975977]] in iteration 738
# The cost function [[0.72958024]] in iteration 739
# The cost function [[0.72940107]] in iteration 740
# The cost function [[0.72922225]] in iteration 741
# The cost function [[0.72904379]] in iteration 742
# The cost function [[0.72886567]] in iteration 743
# The cost function [[0.72868791]] in iteration 744
# The cost function [[0.7285105]] in iteration 745
# The cost function [[0.72833344]] in iteration 746
# The cost function [[0.72815673]] in iteration 747
# The cost function [[0.72798037]] in iteration 748
# The cost function [[0.72780436]] in iteration 749
# The cost function [[0.72762869]] in iteration 750
# The cost function [[0.72745337]] in iteration 751
# The cost function [[0.72727839]] in iteration 752
# The cost function [[0.72710376]] in iteration 753
# The cost function [[0.72692947]] in iteration 754
# The cost function [[0.72675552]] in iteration 755
# The cost function [[0.72658192]] in iteration 756
# The cost function [[0.72640865]] in iteration 757
# The cost function [[0.72623573]] in iteration 758
# The cost function [[0.72606314]] in iteration 759
# The cost function [[0.72589089]] in iteration 760
# The cost function [[0.72571899]] in iteration 761
# The cost function [[0.72554741]] in iteration 762
# The cost function [[0.72537618]] in iteration 763
# The cost function [[0.72520527]] in iteration 764
# The cost function [[0.72503471]] in iteration 765
# The cost function [[0.72486447]] in iteration 766
# The cost function [[0.72469457]] in iteration 767
# The cost function [[0.724525]] in iteration 768
# The cost function [[0.72435576]] in iteration 769
# The cost function [[0.72418685]] in iteration 770
# The cost function [[0.72401828]] in iteration 771
# The cost function [[0.72385003]] in iteration 772
# The cost function [[0.7236821]] in iteration 773
# The cost function [[0.72351451]] in iteration 774
# The cost function [[0.72334724]] in iteration 775
# The cost function [[0.72318029]] in iteration 776
# The cost function [[0.72301367]] in iteration 777
# The cost function [[0.72284738]] in iteration 778
# The cost function [[0.72268141]] in iteration 779
# The cost function [[0.72251575]] in iteration 780
# The cost function [[0.72235043]] in iteration 781
# The cost function [[0.72218542]] in iteration 782
# The cost function [[0.72202073]] in iteration 783
# The cost function [[0.72185636]] in iteration 784
# The cost function [[0.72169231]] in iteration 785
# The cost function [[0.72152858]] in iteration 786
# The cost function [[0.72136516]] in iteration 787
# The cost function [[0.72120206]] in iteration 788
# The cost function [[0.72103927]] in iteration 789
# The cost function [[0.7208768]] in iteration 790
# The cost function [[0.72071465]] in iteration 791
# The cost function [[0.7205528]] in iteration 792
# The cost function [[0.72039127]] in iteration 793
# The cost function [[0.72023005]] in iteration 794
# The cost function [[0.72006914]] in iteration 795
# The cost function [[0.71990854]] in iteration 796
# The cost function [[0.71974825]] in iteration 797
# The cost function [[0.71958827]] in iteration 798
# The cost function [[0.7194286]] in iteration 799
# The cost function [[0.71926923]] in iteration 800
# The cost function [[0.71911017]] in iteration 801
# The cost function [[0.71895142]] in iteration 802
# The cost function [[0.71879297]] in iteration 803
# The cost function [[0.71863482]] in iteration 804
# The cost function [[0.71847698]] in iteration 805
# The cost function [[0.71831944]] in iteration 806
# The cost function [[0.7181622]] in iteration 807
# The cost function [[0.71800526]] in iteration 808
# The cost function [[0.71784863]] in iteration 809
# The cost function [[0.71769229]] in iteration 810
# The cost function [[0.71753625]] in iteration 811
# The cost function [[0.71738052]] in iteration 812
# The cost function [[0.71722507]] in iteration 813
# The cost function [[0.71706993]] in iteration 814
# The cost function [[0.71691508]] in iteration 815
# The cost function [[0.71676053]] in iteration 816
# The cost function [[0.71660627]] in iteration 817
# The cost function [[0.71645231]] in iteration 818
# The cost function [[0.71629864]] in iteration 819
# The cost function [[0.71614526]] in iteration 820
# The cost function [[0.71599217]] in iteration 821
# The cost function [[0.71583938]] in iteration 822
# The cost function [[0.71568687]] in iteration 823
# The cost function [[0.71553466]] in iteration 824
# The cost function [[0.71538273]] in iteration 825
# The cost function [[0.71523109]] in iteration 826
# The cost function [[0.71507975]] in iteration 827
# The cost function [[0.71492868]] in iteration 828
# The cost function [[0.71477791]] in iteration 829
# The cost function [[0.71462742]] in iteration 830
# The cost function [[0.71447721]] in iteration 831
# The cost function [[0.71432729]] in iteration 832
# The cost function [[0.71417766]] in iteration 833
# The cost function [[0.7140283]] in iteration 834
# The cost function [[0.71387923]] in iteration 835
# The cost function [[0.71373044]] in iteration 836
# The cost function [[0.71358193]] in iteration 837
# The cost function [[0.71343371]] in iteration 838
# The cost function [[0.71328576]] in iteration 839
# The cost function [[0.71313809]] in iteration 840
# The cost function [[0.7129907]] in iteration 841
# The cost function [[0.71284359]] in iteration 842
# The cost function [[0.71269675]] in iteration 843
# The cost function [[0.71255019]] in iteration 844
# The cost function [[0.71240391]] in iteration 845
# The cost function [[0.7122579]] in iteration 846
# The cost function [[0.71211216]] in iteration 847
# The cost function [[0.7119667]] in iteration 848
# The cost function [[0.71182151]] in iteration 849
# The cost function [[0.7116766]] in iteration 850
# The cost function [[0.71153196]] in iteration 851
# The cost function [[0.71138759]] in iteration 852
# The cost function [[0.71124348]] in iteration 853
# The cost function [[0.71109965]] in iteration 854
# The cost function [[0.71095609]] in iteration 855
# The cost function [[0.7108128]] in iteration 856
# The cost function [[0.71066977]] in iteration 857
# The cost function [[0.71052702]] in iteration 858
# The cost function [[0.71038452]] in iteration 859
# The cost function [[0.7102423]] in iteration 860
# The cost function [[0.71010034]] in iteration 861
# The cost function [[0.70995865]] in iteration 862
# The cost function [[0.70981722]] in iteration 863
# The cost function [[0.70967605]] in iteration 864
# The cost function [[0.70953515]] in iteration 865
# The cost function [[0.70939451]] in iteration 866
# The cost function [[0.70925413]] in iteration 867
# The cost function [[0.70911401]] in iteration 868
# The cost function [[0.70897415]] in iteration 869
# The cost function [[0.70883456]] in iteration 870
# The cost function [[0.70869522]] in iteration 871
# The cost function [[0.70855614]] in iteration 872
# The cost function [[0.70841732]] in iteration 873
# The cost function [[0.70827875]] in iteration 874
# The cost function [[0.70814045]] in iteration 875
# The cost function [[0.7080024]] in iteration 876
# The cost function [[0.7078646]] in iteration 877
# The cost function [[0.70772707]] in iteration 878
# The cost function [[0.70758978]] in iteration 879
# The cost function [[0.70745275]] in iteration 880
# The cost function [[0.70731597]] in iteration 881
# The cost function [[0.70717945]] in iteration 882
# The cost function [[0.70704318]] in iteration 883
# The cost function [[0.70690716]] in iteration 884
# The cost function [[0.70677139]] in iteration 885
# The cost function [[0.70663587]] in iteration 886
# The cost function [[0.7065006]] in iteration 887
# The cost function [[0.70636558]] in iteration 888
# The cost function [[0.70623081]] in iteration 889
# The cost function [[0.70609629]] in iteration 890
# The cost function [[0.70596201]] in iteration 891
# The cost function [[0.70582799]] in iteration 892
# The cost function [[0.7056942]] in iteration 893
# The cost function [[0.70556067]] in iteration 894
# The cost function [[0.70542738]] in iteration 895
# The cost function [[0.70529433]] in iteration 896
# The cost function [[0.70516153]] in iteration 897
# The cost function [[0.70502897]] in iteration 898
# The cost function [[0.70489666]] in iteration 899
# The cost function [[0.70476458]] in iteration 900
# The cost function [[0.70463275]] in iteration 901
# The cost function [[0.70450116]] in iteration 902
# The cost function [[0.70436982]] in iteration 903
# The cost function [[0.70423871]] in iteration 904
# The cost function [[0.70410784]] in iteration 905
# The cost function [[0.70397721]] in iteration 906
# The cost function [[0.70384682]] in iteration 907
# The cost function [[0.70371666]] in iteration 908
# The cost function [[0.70358675]] in iteration 909
# The cost function [[0.70345707]] in iteration 910
# The cost function [[0.70332763]] in iteration 911
# The cost function [[0.70319842]] in iteration 912
# The cost function [[0.70306945]] in iteration 913
# The cost function [[0.70294072]] in iteration 914
# The cost function [[0.70281221]] in iteration 915
# The cost function [[0.70268394]] in iteration 916
# The cost function [[0.70255591]] in iteration 917
# The cost function [[0.70242811]] in iteration 918
# The cost function [[0.70230054]] in iteration 919
# The cost function [[0.7021732]] in iteration 920
# The cost function [[0.70204609]] in iteration 921
# The cost function [[0.70191921]] in iteration 922
# The cost function [[0.70179256]] in iteration 923
# The cost function [[0.70166615]] in iteration 924
# The cost function [[0.70153996]] in iteration 925
# The cost function [[0.701414]] in iteration 926
# The cost function [[0.70128826]] in iteration 927
# The cost function [[0.70116276]] in iteration 928
# The cost function [[0.70103748]] in iteration 929
# The cost function [[0.70091243]] in iteration 930
# The cost function [[0.7007876]] in iteration 931
# The cost function [[0.700663]] in iteration 932
# The cost function [[0.70053862]] in iteration 933
# The cost function [[0.70041447]] in iteration 934
# The cost function [[0.70029054]] in iteration 935
# The cost function [[0.70016683]] in iteration 936
# The cost function [[0.70004335]] in iteration 937
# The cost function [[0.69992009]] in iteration 938
# The cost function [[0.69979705]] in iteration 939
# The cost function [[0.69967423]] in iteration 940
# The cost function [[0.69955164]] in iteration 941
# The cost function [[0.69942926]] in iteration 942
# The cost function [[0.6993071]] in iteration 943
# The cost function [[0.69918517]] in iteration 944
# The cost function [[0.69906345]] in iteration 945
# The cost function [[0.69894195]] in iteration 946
# The cost function [[0.69882066]] in iteration 947
# The cost function [[0.6986996]] in iteration 948
# The cost function [[0.69857875]] in iteration 949
# The cost function [[0.69845812]] in iteration 950
# The cost function [[0.6983377]] in iteration 951
# The cost function [[0.6982175]] in iteration 952
# The cost function [[0.69809751]] in iteration 953
# The cost function [[0.69797774]] in iteration 954
# The cost function [[0.69785818]] in iteration 955
# The cost function [[0.69773883]] in iteration 956
# The cost function [[0.6976197]] in iteration 957
# The cost function [[0.69750078]] in iteration 958
# The cost function [[0.69738207]] in iteration 959
# The cost function [[0.69726357]] in iteration 960
# The cost function [[0.69714529]] in iteration 961
# The cost function [[0.69702721]] in iteration 962
# The cost function [[0.69690934]] in iteration 963
# The cost function [[0.69679169]] in iteration 964
# ...
# The cost function [[0.61095796]] in iteration 8465
# The cost function [[0.61095784]] in iteration 8466
# The cost function [[0.61095771]] in iteration 8467
# The cost function [[0.61095759]] in iteration 8468
# The cost function [[0.61095747]] in iteration 8469
# The cost function [[0.61095734]] in iteration 8470
# The cost function [[0.61095722]] in iteration 8471
# The cost function [[0.61095709]] in iteration 8472
# The cost function [[0.61095697]] in iteration 8473
# The cost function [[0.61095685]] in iteration 8474
# The cost function [[0.61095672]] in iteration 8475
# The cost function [[0.6109566]] in iteration 8476
# The cost function [[0.61095648]] in iteration 8477
# The cost function [[0.61095635]] in iteration 8478
# The cost function [[0.61095623]] in iteration 8479
# The cost function [[0.61095611]] in iteration 8480
# The cost function [[0.61095598]] in iteration 8481
# The cost function [[0.61095586]] in iteration 8482
# The cost function [[0.61095574]] in iteration 8483
# The cost function [[0.61095562]] in iteration 8484
# The cost function [[0.61095549]] in iteration 8485
# The cost function [[0.61095537]] in iteration 8486
# The cost function [[0.61095525]] in iteration 8487
# The cost function [[0.61095513]] in iteration 8488
# The cost function [[0.610955]] in iteration 8489
# The cost function [[0.61095488]] in iteration 8490
# The cost function [[0.61095476]] in iteration 8491
# The cost function [[0.61095464]] in iteration 8492
# The cost function [[0.61095452]] in iteration 8493
# The cost function [[0.61095439]] in iteration 8494
# The cost function [[0.61095427]] in iteration 8495
# The cost function [[0.61095415]] in iteration 8496
# The cost function [[0.61095403]] in iteration 8497
# The cost function [[0.61095391]] in iteration 8498
# The cost function [[0.61095379]] in iteration 8499
# The cost function [[0.61095367]] in iteration 8500
# The cost function [[0.61095354]] in iteration 8501
# The cost function [[0.61095342]] in iteration 8502
# The cost function [[0.6109533]] in iteration 8503
# The cost function [[0.61095318]] in iteration 8504
# The cost function [[0.61095306]] in iteration 8505
# The cost function [[0.61095294]] in iteration 8506
# The cost function [[0.61095282]] in iteration 8507
# The cost function [[0.6109527]] in iteration 8508
# The cost function [[0.61095258]] in iteration 8509
# The cost function [[0.61095246]] in iteration 8510
# The cost function [[0.61095234]] in iteration 8511
# The cost function [[0.61095222]] in iteration 8512
# The cost function [[0.6109521]] in iteration 8513
# The cost function [[0.61095198]] in iteration 8514
# The cost function [[0.61095186]] in iteration 8515
# The cost function [[0.61095174]] in iteration 8516
# The cost function [[0.61095162]] in iteration 8517
# The cost function [[0.6109515]] in iteration 8518
# The cost function [[0.61095138]] in iteration 8519
# The cost function [[0.61095126]] in iteration 8520
# The cost function [[0.61095114]] in iteration 8521
# The cost function [[0.61095102]] in iteration 8522
# The cost function [[0.6109509]] in iteration 8523
# The cost function [[0.61095078]] in iteration 8524
# The cost function [[0.61095066]] in iteration 8525
# The cost function [[0.61095054]] in iteration 8526
# The cost function [[0.61095042]] in iteration 8527
# The cost function [[0.6109503]] in iteration 8528
# The cost function [[0.61095018]] in iteration 8529
# The cost function [[0.61095007]] in iteration 8530
# The cost function [[0.61094995]] in iteration 8531
# The cost function [[0.61094983]] in iteration 8532
# The cost function [[0.61094971]] in iteration 8533
# The cost function [[0.61094959]] in iteration 8534
# The cost function [[0.61094947]] in iteration 8535
# The cost function [[0.61094935]] in iteration 8536
# The cost function [[0.61094924]] in iteration 8537
# The cost function [[0.61094912]] in iteration 8538
# The cost function [[0.610949]] in iteration 8539
# The cost function [[0.61094888]] in iteration 8540
# The cost function [[0.61094876]] in iteration 8541
# The cost function [[0.61094865]] in iteration 8542
# The cost function [[0.61094853]] in iteration 8543
# The cost function [[0.61094841]] in iteration 8544
# The cost function [[0.61094829]] in iteration 8545
# The cost function [[0.61094818]] in iteration 8546
# The cost function [[0.61094806]] in iteration 8547
# The cost function [[0.61094794]] in iteration 8548
# The cost function [[0.61094782]] in iteration 8549
# The cost function [[0.61094771]] in iteration 8550
# The cost function [[0.61094759]] in iteration 8551
# The cost function [[0.61094747]] in iteration 8552
# The cost function [[0.61094736]] in iteration 8553
# The cost function [[0.61094724]] in iteration 8554
# The cost function [[0.61094712]] in iteration 8555
# The cost function [[0.61094701]] in iteration 8556
# The cost function [[0.61094689]] in iteration 8557
# The cost function [[0.61094677]] in iteration 8558
# The cost function [[0.61094666]] in iteration 8559
# The cost function [[0.61094654]] in iteration 8560
# The cost function [[0.61094642]] in iteration 8561
# The cost function [[0.61094631]] in iteration 8562
# The cost function [[0.61094619]] in iteration 8563
# The cost function [[0.61094608]] in iteration 8564
# The cost function [[0.61094596]] in iteration 8565
# The cost function [[0.61094584]] in iteration 8566
# The cost function [[0.61094573]] in iteration 8567
# The cost function [[0.61094561]] in iteration 8568
# The cost function [[0.6109455]] in iteration 8569
# The cost function [[0.61094538]] in iteration 8570
# The cost function [[0.61094527]] in iteration 8571
# The cost function [[0.61094515]] in iteration 8572
# The cost function [[0.61094503]] in iteration 8573
# The cost function [[0.61094492]] in iteration 8574
# The cost function [[0.6109448]] in iteration 8575
# The cost function [[0.61094469]] in iteration 8576
# The cost function [[0.61094457]] in iteration 8577
# The cost function [[0.61094446]] in iteration 8578
# The cost function [[0.61094434]] in iteration 8579
# The cost function [[0.61094423]] in iteration 8580
# The cost function [[0.61094411]] in iteration 8581
# The cost function [[0.610944]] in iteration 8582
# The cost function [[0.61094389]] in iteration 8583
# The cost function [[0.61094377]] in iteration 8584
# The cost function [[0.61094366]] in iteration 8585
# The cost function [[0.61094354]] in iteration 8586
# The cost function [[0.61094343]] in iteration 8587
# The cost function [[0.61094331]] in iteration 8588
# The cost function [[0.6109432]] in iteration 8589
# The cost function [[0.61094309]] in iteration 8590
# The cost function [[0.61094297]] in iteration 8591
# The cost function [[0.61094286]] in iteration 8592
# The cost function [[0.61094274]] in iteration 8593
# The cost function [[0.61094263]] in iteration 8594
# The cost function [[0.61094252]] in iteration 8595
# The cost function [[0.6109424]] in iteration 8596
# The cost function [[0.61094229]] in iteration 8597
# The cost function [[0.61094218]] in iteration 8598
# The cost function [[0.61094206]] in iteration 8599
# The cost function [[0.61094195]] in iteration 8600
# The cost function [[0.61094184]] in iteration 8601
# The cost function [[0.61094172]] in iteration 8602
# The cost function [[0.61094161]] in iteration 8603
# The cost function [[0.6109415]] in iteration 8604
# The cost function [[0.61094139]] in iteration 8605
# The cost function [[0.61094127]] in iteration 8606
# The cost function [[0.61094116]] in iteration 8607
# The cost function [[0.61094105]] in iteration 8608
# The cost function [[0.61094094]] in iteration 8609
# The cost function [[0.61094082]] in iteration 8610
# The cost function [[0.61094071]] in iteration 8611
# The cost function [[0.6109406]] in iteration 8612
# The cost function [[0.61094049]] in iteration 8613
# The cost function [[0.61094037]] in iteration 8614
# The cost function [[0.61094026]] in iteration 8615
# The cost function [[0.61094015]] in iteration 8616
# The cost function [[0.61094004]] in iteration 8617
# The cost function [[0.61093993]] in iteration 8618
# The cost function [[0.61093982]] in iteration 8619
# The cost function [[0.6109397]] in iteration 8620
# The cost function [[0.61093959]] in iteration 8621
# The cost function [[0.61093948]] in iteration 8622
# The cost function [[0.61093937]] in iteration 8623
# The cost function [[0.61093926]] in iteration 8624
# The cost function [[0.61093915]] in iteration 8625
# The cost function [[0.61093904]] in iteration 8626
# The cost function [[0.61093892]] in iteration 8627
# The cost function [[0.61093881]] in iteration 8628
# The cost function [[0.6109387]] in iteration 8629
# The cost function [[0.61093859]] in iteration 8630
# The cost function [[0.61093848]] in iteration 8631
# The cost function [[0.61093837]] in iteration 8632
# The cost function [[0.61093826]] in iteration 8633
# The cost function [[0.61093815]] in iteration 8634
# The cost function [[0.61093804]] in iteration 8635
# The cost function [[0.61093793]] in iteration 8636
# The cost function [[0.61093782]] in iteration 8637
# The cost function [[0.61093771]] in iteration 8638
# The cost function [[0.6109376]] in iteration 8639
# The cost function [[0.61093749]] in iteration 8640
# The cost function [[0.61093738]] in iteration 8641
# The cost function [[0.61093727]] in iteration 8642
# The cost function [[0.61093716]] in iteration 8643
# The cost function [[0.61093705]] in iteration 8644
# The cost function [[0.61093694]] in iteration 8645
# The cost function [[0.61093683]] in iteration 8646
# The cost function [[0.61093672]] in iteration 8647
# The cost function [[0.61093661]] in iteration 8648
# The cost function [[0.6109365]] in iteration 8649
# The cost function [[0.61093639]] in iteration 8650
# The cost function [[0.61093628]] in iteration 8651
# The cost function [[0.61093617]] in iteration 8652
# The cost function [[0.61093606]] in iteration 8653
# The cost function [[0.61093595]] in iteration 8654
# The cost function [[0.61093584]] in iteration 8655
# The cost function [[0.61093574]] in iteration 8656
# The cost function [[0.61093563]] in iteration 8657
# The cost function [[0.61093552]] in iteration 8658
# The cost function [[0.61093541]] in iteration 8659
# The cost function [[0.6109353]] in iteration 8660
# The cost function [[0.61093519]] in iteration 8661
# The cost function [[0.61093508]] in iteration 8662
# The cost function [[0.61093498]] in iteration 8663
# The cost function [[0.61093487]] in iteration 8664
# The cost function [[0.61093476]] in iteration 8665
# The cost function [[0.61093465]] in iteration 8666
# The cost function [[0.61093454]] in iteration 8667
# The cost function [[0.61093444]] in iteration 8668
# The cost function [[0.61093433]] in iteration 8669
# The cost function [[0.61093422]] in iteration 8670
# The cost function [[0.61093411]] in iteration 8671
# The cost function [[0.610934]] in iteration 8672
# The cost function [[0.6109339]] in iteration 8673
# The cost function [[0.61093379]] in iteration 8674
# The cost function [[0.61093368]] in iteration 8675
# The cost function [[0.61093357]] in iteration 8676
# The cost function [[0.61093347]] in iteration 8677
# The cost function [[0.61093336]] in iteration 8678
# The cost function [[0.61093325]] in iteration 8679
# The cost function [[0.61093315]] in iteration 8680
# The cost function [[0.61093304]] in iteration 8681
# The cost function [[0.61093293]] in iteration 8682
# The cost function [[0.61093282]] in iteration 8683
# The cost function [[0.61093272]] in iteration 8684
# The cost function [[0.61093261]] in iteration 8685
# The cost function [[0.6109325]] in iteration 8686
# The cost function [[0.6109324]] in iteration 8687
# The cost function [[0.61093229]] in iteration 8688
# The cost function [[0.61093218]] in iteration 8689
# The cost function [[0.61093208]] in iteration 8690
# The cost function [[0.61093197]] in iteration 8691
# The cost function [[0.61093187]] in iteration 8692
# The cost function [[0.61093176]] in iteration 8693
# The cost function [[0.61093165]] in iteration 8694
# The cost function [[0.61093155]] in iteration 8695
# The cost function [[0.61093144]] in iteration 8696
# The cost function [[0.61093134]] in iteration 8697
# The cost function [[0.61093123]] in iteration 8698
# The cost function [[0.61093112]] in iteration 8699
# The cost function [[0.61093102]] in iteration 8700
# The cost function [[0.61093091]] in iteration 8701
# The cost function [[0.61093081]] in iteration 8702
# The cost function [[0.6109307]] in iteration 8703
# The cost function [[0.6109306]] in iteration 8704
# The cost function [[0.61093049]] in iteration 8705
# The cost function [[0.61093039]] in iteration 8706
# The cost function [[0.61093028]] in iteration 8707
# The cost function [[0.61093018]] in iteration 8708
# The cost function [[0.61093007]] in iteration 8709
# The cost function [[0.61092997]] in iteration 8710
# The cost function [[0.61092986]] in iteration 8711
# The cost function [[0.61092976]] in iteration 8712
# The cost function [[0.61092965]] in iteration 8713
# The cost function [[0.61092955]] in iteration 8714
# The cost function [[0.61092944]] in iteration 8715
# The cost function [[0.61092934]] in iteration 8716
# The cost function [[0.61092923]] in iteration 8717
# The cost function [[0.61092913]] in iteration 8718
# The cost function [[0.61092903]] in iteration 8719
# The cost function [[0.61092892]] in iteration 8720
# The cost function [[0.61092882]] in iteration 8721
# The cost function [[0.61092871]] in iteration 8722
# The cost function [[0.61092861]] in iteration 8723
# The cost function [[0.61092851]] in iteration 8724
# The cost function [[0.6109284]] in iteration 8725
# The cost function [[0.6109283]] in iteration 8726
# The cost function [[0.61092819]] in iteration 8727
# The cost function [[0.61092809]] in iteration 8728
# The cost function [[0.61092799]] in iteration 8729
# The cost function [[0.61092788]] in iteration 8730
# The cost function [[0.61092778]] in iteration 8731
# The cost function [[0.61092768]] in iteration 8732
# The cost function [[0.61092757]] in iteration 8733
# The cost function [[0.61092747]] in iteration 8734
# The cost function [[0.61092737]] in iteration 8735
# The cost function [[0.61092726]] in iteration 8736
# The cost function [[0.61092716]] in iteration 8737
# The cost function [[0.61092706]] in iteration 8738
# The cost function [[0.61092696]] in iteration 8739
# The cost function [[0.61092685]] in iteration 8740
# The cost function [[0.61092675]] in iteration 8741
# The cost function [[0.61092665]] in iteration 8742
# The cost function [[0.61092655]] in iteration 8743
# The cost function [[0.61092644]] in iteration 8744
# The cost function [[0.61092634]] in iteration 8745
# The cost function [[0.61092624]] in iteration 8746
# The cost function [[0.61092614]] in iteration 8747
# The cost function [[0.61092603]] in iteration 8748
# The cost function [[0.61092593]] in iteration 8749
# The cost function [[0.61092583]] in iteration 8750
# The cost function [[0.61092573]] in iteration 8751
# The cost function [[0.61092563]] in iteration 8752
# The cost function [[0.61092552]] in iteration 8753
# The cost function [[0.61092542]] in iteration 8754
# The cost function [[0.61092532]] in iteration 8755
# The cost function [[0.61092522]] in iteration 8756
# The cost function [[0.61092512]] in iteration 8757
# The cost function [[0.61092502]] in iteration 8758
# The cost function [[0.61092491]] in iteration 8759
# The cost function [[0.61092481]] in iteration 8760
# The cost function [[0.61092471]] in iteration 8761
# The cost function [[0.61092461]] in iteration 8762
# The cost function [[0.61092451]] in iteration 8763
# The cost function [[0.61092441]] in iteration 8764
# The cost function [[0.61092431]] in iteration 8765
# The cost function [[0.61092421]] in iteration 8766
# The cost function [[0.61092411]] in iteration 8767
# The cost function [[0.610924]] in iteration 8768
# The cost function [[0.6109239]] in iteration 8769
# The cost function [[0.6109238]] in iteration 8770
# The cost function [[0.6109237]] in iteration 8771
# The cost function [[0.6109236]] in iteration 8772
# The cost function [[0.6109235]] in iteration 8773
# The cost function [[0.6109234]] in iteration 8774
# The cost function [[0.6109233]] in iteration 8775
# The cost function [[0.6109232]] in iteration 8776
# The cost function [[0.6109231]] in iteration 8777
# The cost function [[0.610923]] in iteration 8778

# %%
print(Q0_new,"\n\n\n",Q1_new)
# Out:
# [[-9.54423017]]
#
#
#  [[4.78645251]
#  [5.68392434]
#  [5.05448477]
#  [2.94854175]]

# %%
len(iterations)
# Out:
# 8778

# %%
plt.scatter(iterations,loss)

# %% [markdown]
# ### performing testing

# %%
p =Q0_new +np.dot(pure_testing_data,Q1_new)

# %%
p
# Out:
# array([[-0.123663  ],
#        [ 2.37073144],
#        [ 1.80471941],
#        [ 0.05609199],
#        [ 0.70322938],
#        [ 2.25502372],
#        [-3.51695414],
#        [ 1.56918561],
#        [ 2.67273483],
#        [-0.820555  ],
#        [ 0.97912863],
#        [ 1.26605007],
#        [-0.84847022],
#        [-2.01653601],
#        [ 2.86802521],
#        [ 1.15317942],
#        [ 2.77732119],
#        [ 2.85985849]])

# %%
sigmoid_testing = ((1)/(1+np.exp(-p)))

# %%
greater=[]
for i in range(sigmoid_testing.shape[0]):
  if sigmoid_testing[i]>=0.5:
    greater.append(int(1))
  else:
    greater.append(int(0))
#print(greater)
greater = np.array(greater)
np.count_nonzero(greater)
# Out:
# 13

# %%
greater = greater.reshape(greater.shape[0],1)
greater.shape
# Out:
# (18, 1)

# %%
C_test=np.array(C_test)
np.count_nonzero(C_test)
# Out:
# 9

# %%
np.count_nonzero(greater == C_test)/ C_test.shape[0]
# Out:
# 0.7777777777777778

# %%
print("Accuracy : ", round(np.count_nonzero(greater == C_test) / C_test.shape[0] * 100 , 2) , " %")
# Out:
# Accuracy :  77.78  %
